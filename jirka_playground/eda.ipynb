# %% [markdown]
# # About
# ### this notebook's goal is to do some basic EDA to get idea of how the data look like
#
# # Main tasks:
#  - Sečíst přítoky a odečíst odtoky z ČR
#  - Porovnat letošní rok oproti minulými - jsme na tom lépe nebo hůře?
#     - co kdybychom vypli flow in? - Dívat se na celoevropská data
#
#
# # Sub tasks:
#  - Zjistit co znamená reálně firm, ověřit jestli je tam nějaký limit na denní odběr třeba kvůli nějakým fyzikálním vlastnostem
#  - vliv teploty
# # Data
# ### data is availible in folder data, in 4 subfolders:
#  - flow_in are data about gas flowing in cz
#  - flow_out data about gas flowing out of cz
#  - storage_in - from CZ to storage
#  - storage_out - from storage to CZ
#
# ### all xlsx files have only ONE sheet

# %%
# Imports:
# %load_ext autoreload
# %autoreload 2
from tqdm import tqdm
import time
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.ticker as plticker
from datetime import datetime
import plotly.graph_objects as go
import copy
from plotly.subplots import make_subplots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def create_dict_datasets(data_folder: str = '../data') -> dict:
    ''' 
    Loads all datasets into dictionaries
    with names same as data folders in 
    :param data_folder: folder where all dataset folders are saved
    '''
    dict_of_all = {}
    #get all dataset folders
    datasets = os.listdir(data_folder)
    #remove hidden files
    dict_of_all = {dataset:0 for dataset in datasets  if not dataset.startswith('.')}
    print(f'initiating for dataset groups: {list(dict_of_all.keys())}')
    for dataset in dict_of_all.keys():
        print(f'loading data for dataset group: {dataset}')
        # list all files in dataset folder
        files_in_dataset = os.listdir(f'{data_folder}/{dataset}')
        # initiate dictionary
        files_in_dataset = {k:0 for k in files_in_dataset}
        dict_of_all[dataset] = files_in_dataset
        for file in dict_of_all[dataset].keys():
            # assign dataframe to each filename
            dict_of_all[dataset][file] = pd.read_excel(f'{data_folder}/{dataset}/{file}')
    return dict_of_all

# %%
dict_of_all = create_dict_datasets()

# %%
dict_of_all['storage_out'].keys()
dict_of_all['storage_in'].keys()
dict_of_all['flow_out'].keys()
dict_of_all['flow_in'].keys()

# %%
#get first dataframe from each dataset folder
storage_out_east_to_cz = dict_of_all['storage_out'][list(dict_of_all['storage_out'].keys())[0]]
storage_in_cz_to_center = dict_of_all['storage_in'][list(dict_of_all['storage_in'].keys())[0]]
flow_in_germany_north_the_lowest_to_cz = dict_of_all['flow_in'][list(dict_of_all['flow_in'].keys())[0]]
flow_out_cz_to_germany_barandov_opal_most_norther = dict_of_all['flow_out'][list(dict_of_all['flow_out'].keys())[0]]

# %%
flow_in_germany_north_the_lowest_to_cz.info()

# %%
flow_out_cz_to_germany_barandov_opal_most_norther.info()

# %%
storage_in_cz_to_center.info()

# %%
storage_out_east_to_cz.info()

# %%
indicator_groups = storage_out_east_to_cz['indicator'].unique()
print(f'This dataset can be divided by column indicator into 2 groups: {indicator_groups}')
print(f'group {indicator_groups[0]} has this amount of zeros in "value" column:')
storage_out_east_to_cz.loc[storage_out_east_to_cz.indicator == 'Firm Available'].loc[storage_out_east_to_cz['value'] == 0]['value'].nunique()
print(f'group {indicator_groups[1]}: has this amount of unique values for "value" column where its value is == 0:')
storage_out_east_to_cz.loc[storage_out_east_to_cz.indicator == 'Physical Flow'].loc[storage_out_east_to_cz['value'] == 0].nunique()

storage_out_east_to_cz['flowStatus'].unique()
storage_out_east_to_cz.loc[storage_out_east_to_cz.flowStatus == 'Confirmed']

# %%
def firm_flow(default_data):
    data = copy.deepcopy(default_data)
    firm_availible_data = data.loc[data.indicator == 'Firm Available']
    physical_flow_data = data.loc[data.indicator == 'Physical Flow']
    return firm_availible_data, physical_flow_data

# %%
def prepare_data(data):
    data['periodFrom']  = pd.to_datetime(data['periodFrom'])
    data['periodFrom'] = data['periodFrom'].apply(lambda x: datetime.strftime(x, '%Y-%m-%d'))
    return data

# %%
def plot_values(default_data):
    data = copy.deepcopy(default_data)
    fig = plt.figure(figsize=[14,10])
    ax = plt.subplot(111)
    data = prepare_data(data)
    # l = ax.fill_between(data['obdobi'],data['UK4/UK3'])
    ax.scatter(data['periodFrom'],data['value'])

    # set the basic properties
    ax.set_xlabel('date')
    ax.set_ylabel('value (kWh/d)')
    ax.set_title('time series of stored amount of gas')
    # ax.tick_params(axis="x", labelsie=6) 
    start, end = ax.get_xlim()
    loc = plticker.MultipleLocator(base=50.0)
    ax.xaxis.set_major_locator(loc)
    fig.show()

# %%
def plotly_plot_values(default_data,graph_type = 'scatter'):
    data = prepare_data(default_data)
    fig = make_subplots(rows=1, cols=1)
    if graph_type == 'scatter':
        fig.add_trace(go.Scatter(x = data['periodFrom'], y = data['value']),row=1,col=1)
    elif graph_type == 'hist':
        fig.add_trace(go.Histogram(x = data['periodFrom'], y = data['value']),row=1,col=1)
    # elif graph_type == 'line':
        # fig = go.Scatter(x = data['periodFrom'], y = data['value'])
    fig.show()

# %%
def plotly_subplot_values(default_data1, default_data2,graph_type = 'scatter'):
    data1 = prepare_data(default_data1)
    data2 = prepare_data(default_data2)
    fig = make_subplots(rows=1, cols=2)
    if graph_type == 'scatter':

        fig.add_trace(
            go.Scatter(x = data1['periodFrom'], y = data1['value']), row=1, col=1)
        

        fig.add_trace(
            go.Scatter(x = data2['periodFrom'], y = data2['value']), row=1, col=2)
        
    elif graph_type == 'hist':
        
        fig.add_trace(
            go.Histogram(x = data1['periodFrom'], y = data1['value']), row=1, col=1)
        

        fig.add_trace(
            go.Histogram(x = data2['periodFrom'], y = data2['value']),  row=1, col=2)
        
    # elif graph_type == 'line':
        # fig = go.Scatter(x = data['periodFrom'], y = data['value'])
    fig.update_layout(height=600, width=800, title_text="Side By Side Subplots")
    fig.show()

# %%
firm_availible_data,physical_flow_data = firm_flow(storage_out_east_to_cz)

# %%
plotly_subplot_values(firm_availible_data,physical_flow_data)

# %%
flow_in_firm_availible, flow_in_physical_flow = firm_flow(flow_in_germany_north_the_lowest_to_cz)

# %%
flow_in_germany_north_the_lowest_to_cz
# Out:
#           indicator periodType        periodFrom          periodTo  \
# 0    Firm Available        day  2020-01-22 06:00  2040-01-01 06:00
# 1     Physical Flow        day  2020-01-21 06:00  2020-01-22 06:00
# 2     Physical Flow        day  2020-01-22 06:00  2020-01-23 06:00
# 3     Physical Flow        day  2020-01-23 06:00  2020-01-24 06:00
# 4     Physical Flow        day  2020-01-24 06:00  2020-01-25 06:00
# ..              ...        ...               ...               ...
# 995   Physical Flow        day  2022-10-11 06:00  2022-10-12 06:00
# 996   Physical Flow        day  2022-10-12 06:00  2022-10-13 06:00
# 997   Physical Flow        day  2022-10-13 06:00  2022-10-14 06:00
# 998   Physical Flow        day  2022-10-14 06:00  2022-10-15 06:00
# 999   Physical Flow        day  2022-10-15 06:00  2022-10-16 06:00
#
#            tsoEicCode operatorLabel                     pointLabel  \
# 0    21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 1    21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 2    21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 3    21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 4    21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# ..                ...           ...                            ...
# 995  21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 996  21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 997  21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 998  21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
# 999  21X000000001304L       NET4GAS  Deutschneudorf EUGAL Brandov
#
#     tsoItemIdentifier directionKey   unit  ...  generalRemarks      value  \
# 0    21Z0000000004839        entry  kWh/d  ...             NaN          0
# 1    21Z0000000004839        entry  kWh/d  ...             NaN  610403499
# 2    21Z0000000004839        entry  kWh/d  ...             NaN  615611363
# 3    21Z0000000004839        entry  kWh/d  ...             NaN  610985123
# 4    21Z0000000004839        entry  kWh/d  ...             NaN  611512284
# ..                ...          ...    ...  ...             ...        ...
# 995  21Z0000000004839        entry  kWh/d  ...             NaN   72004364
# 996  21Z0000000004839        entry  kWh/d  ...             NaN   71995753
# 997  21Z0000000004839        entry  kWh/d  ...             NaN   59995208
# 998  21Z0000000004839        entry  kWh/d  ...             NaN   54998128
# 999  21Z0000000004839        entry  kWh/d  ...             NaN          0
#
#      lastUpdateDateTime isUnlimited   flowStatus isCamRelevant isNA  \
# 0      2020-05-31 09:42          no          NaN            no  NaN
# 1      2020-01-22 12:19         NaN  Provisional           yes  NaN
# 2      2020-01-23 12:05         NaN  Provisional           yes  NaN
# 3      2020-01-24 12:05         NaN  Provisional           yes  NaN
# 4      2020-01-25 12:05         NaN  Provisional           yes  NaN
# ..                  ...         ...          ...           ...  ...
# 995    2022-10-12 12:16         NaN  Provisional            no  NaN
# 996    2022-10-14 02:29         NaN  Provisional            no  NaN
# 997    2022-10-14 22:36         NaN  Provisional            no  NaN
# 998    2022-10-15 15:49         NaN  Provisional            no  NaN
# 999    2022-10-15 15:49         NaN  Provisional            no  NaN
#
#      isCmpRelevant interruptionCalculationRemark  isArchived
# 0              NaN                           NaN         NaN
# 1              yes                           NaN         0.0
# 2              yes                           NaN         0.0
# 3              yes                           NaN         0.0
# 4              yes                           NaN         0.0
# ..             ...                           ...         ...
# 995             no                           NaN         0.0
# 996             no                           NaN         0.0
# 997             no                           NaN         0.0
# 998             no                           NaN         0.0
# 999             no                           NaN         0.0
#
# [1000 rows x 21 columns]

# %%
plotly_plot_values(flow_in_physical_flow, 'scatter')

# %%
flow_out_cz_to_germany_barandov_opal_most_norther['value'].unique()
# Out:
# array([0])

# %%
flow_out_cz_to_germany_barandov_opal_most_norther
# Out:
#            indicator periodType        periodFrom          periodTo  \
# 0     Firm Available        day  2013-10-16 06:00  2040-01-01 06:00
# 1      Physical Flow        day  2017-10-15 06:00  2017-10-16 06:00
# 2      Physical Flow        day  2017-10-16 06:00  2017-10-17 06:00
# 3      Physical Flow        day  2017-10-17 06:00  2017-10-18 06:00
# 4      Physical Flow        day  2017-10-18 06:00  2017-10-19 06:00
# ...              ...        ...               ...               ...
# 1823   Physical Flow        day  2022-10-11 06:00  2022-10-12 06:00
# 1824   Physical Flow        day  2022-10-12 06:00  2022-10-13 06:00
# 1825   Physical Flow        day  2022-10-13 06:00  2022-10-14 06:00
# 1826   Physical Flow        day  2022-10-14 06:00  2022-10-15 06:00
# 1827   Physical Flow        day  2022-10-15 06:00  2022-10-16 06:00
#
#             tsoEicCode operatorLabel         pointLabel tsoItemIdentifier  \
# 0     21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 1     21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 2     21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 3     21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 4     21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# ...                ...           ...                ...               ...
# 1823  21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 1824  21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 1825  21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 1826  21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
# 1827  21X000000001304L       NET4GAS  Brandov-OPAL (DE)  21Z000000000242V
#
#      directionKey   unit  ...  generalRemarks  value  lastUpdateDateTime  \
# 0            exit  kWh/d  ...             NaN      0    2020-04-15 13:44
# 1            exit  kWh/d  ...             NaN      0    2017-11-12 04:18
# 2            exit  kWh/d  ...             NaN      0    2017-11-12 04:18
# 3            exit  kWh/d  ...             NaN      0    2017-11-12 04:18
# 4            exit  kWh/d  ...             NaN      0    2017-11-12 04:18
# ...           ...    ...  ...             ...    ...                 ...
# 1823         exit  kWh/d  ...             NaN      0    2022-10-12 12:16
# 1824         exit  kWh/d  ...             NaN      0    2022-10-14 02:29
# 1825         exit  kWh/d  ...             NaN      0    2022-10-14 22:36
# 1826         exit  kWh/d  ...             NaN      0    2022-10-15 15:49
# 1827         exit  kWh/d  ...             NaN      0    2022-10-15 15:49
#
#      isUnlimited   flowStatus isCamRelevant isNA  isCmpRelevant  \
# 0             no          NaN           yes  NaN            NaN
# 1            NaN    Confirmed           NaN  NaN            NaN
# 2            NaN    Confirmed           NaN  NaN            NaN
# 3            NaN    Confirmed           NaN  NaN            NaN
# 4            NaN    Confirmed           NaN  NaN            NaN
# ...          ...          ...           ...  ...            ...
# 1823         NaN  Provisional            no  NaN             no
# 1824         NaN  Provisional            no  NaN             no
# 1825         NaN  Provisional            no  NaN             no
# 1826         NaN  Provisional            no  NaN             no
# 1827         NaN  Provisional            no  NaN             no
#
#      interruptionCalculationRemark  isArchived
# 0                              NaN         NaN
# 1                              NaN         0.0
# 2                              NaN         0.0
# 3                              NaN         0.0
# 4                              NaN         0.0
# ...                            ...         ...
# 1823                           NaN         0.0
# 1824                           NaN         0.0
# 1825                           NaN         0.0
# 1826                           NaN         0.0
# 1827                           NaN         0.0
#
# [1828 rows x 21 columns]

# %%
# flow_out_cz_to_germany_barandov_opal_most_norther['value'].unique()
# this does not make sense to do...
# flow_out_firm_availible, flow_out_physical_flow = firm_flow(flow_out_cz_to_germany_barandov_opal_most_norther)
# plotly_plot_values(flow_out_physical_flow, 'scatter')
# Out:
# array([0])

# %%
storage_in_firm_availible,storage_out_physical_flow = firm_flow(storage_in_cz_to_center)

# %%
plotly_plot_values(storage_in_firm_availible, 'scatter')

# %%
# flow_in_germany_north_the_lowest_to_cz.info()
# flow_out_cz_to_germany_barandov_opal_most_norther.info()
# storage_in_cz_to_center.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   indicator                      1000 non-null   object
#  1   periodType                     1000 non-null   object
#  2   periodFrom                     1000 non-null   object
#  3   periodTo                       1000 non-null   object
#  4   tsoEicCode                     1000 non-null   object
#  5   operatorLabel                  1000 non-null   object
#  6   pointLabel                     1000 non-null   object
#  7   tsoItemIdentifier              1000 non-null   object
#  8   directionKey                   1000 non-null   object
#  9   unit                           1000 non-null   object
#  10  itemRemarks                    0 non-null      float64
#  11  generalRemarks                 0 non-null      float64
#  12  value                          1000 non-null   int64
#  13  lastUpdateDateTime             1000 non-null   object
#  14  isUnlimited                    1 non-null      object
#  15  flowStatus                     999 non-null    object
#  16  isCamRelevant                  1000 non-null   object
#  17  isNA                           0 non-null      float64
#  18  isCmpRelevant                  999 non-null    object
#  19  interruptionCalculationRemark  0 non-null      float64
#  20  isArchived                     999 non-null    float64
# dtypes: float64(5), int64(1), object(15)
# memory usage: 164.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1828 entries, 0 to 1827
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   indicator                      1828 non-null   object
#  1   periodType                     1828 non-null   object
#  2   periodFrom                     1828 non-null   object
#  3   periodTo                       1828 non-null   object
#  4   tsoEicCode                     1828 non-null   object
#  5   operatorLabel                  1828 non-null   object
#  6   pointLabel                     1828 non-null   object
#  7   tsoItemIdentifier              1828 non-null   object
#  8   directionKey                   1828 non-null   object
#  9   unit                           1828 non-null   object
#  10  itemRemarks                    0 non-null      float64
#  11  generalRemarks                 0 non-null      float64
#  12  value                          1828 non-null   int64
#  13  lastUpdateDateTime             1828 non-null   object
#  14  isUnlimited                    1 non-null      object
#  15  flowStatus                     1827 non-null   object
#  16  isCamRelevant                  1660 non-null   object
#  17  isNA                           0 non-null      float64
#  18  isCmpRelevant                  1659 non-null   object
#  19  interruptionCalculationRemark  0 non-null      float64
#  20  isArchived                     1827 non-null   float64
# dtypes: float64(5), int64(1), object(15)
# memory usage: 300.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2261 entries, 0 to 2260
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   indicator                      2261 non-null   object
#  1   periodType                     2261 non-null   object
#  2   periodFrom                     2261 non-null   object
#  3   periodTo                       2261 non-null   object
#  4   tsoEicCode                     2261 non-null   object
#  5   operatorLabel                  2261 non-null   object
#  6   pointLabel                     2261 non-null   object
#  7   tsoItemIdentifier              2261 non-null   object
#  8   directionKey                   2261 non-null   object
#  9   unit                           2261 non-null   object
#  10  itemRemarks                    0 non-null      float64
#  11  generalRemarks                 0 non-null      float64
#  12  value                          2261 non-null   int64
#  13  lastUpdateDateTime             2261 non-null   object
#  14  isUnlimited                    433 non-null    object
#  15  flowStatus                     1828 non-null   object
#  16  isCamRelevant                  663 non-null    object
#  17  isNA                           0 non-null      float64
#  18  isCmpRelevant                  230 non-null    object
#  19  interruptionCalculationRemark  0 non-null      float64
#  20  isArchived                     1828 non-null   float64
# dtypes: float64(5), int64(1), object(15)
# memory usage: 371.1+ KB
